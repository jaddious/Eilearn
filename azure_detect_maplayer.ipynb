# %% [markdown]
# # Dectect Eilands on a map layer
#
# This notebook takes all the tiles of a layer map and uses the Azure Custom Vision model downloaded from the Azure portal to detect the Eilands on the map.
#
# Download the model from the Azure portal: https://www.customvision.ai/projects/2d90f277-ac1c-490c-9b14-34fee8011de7#/performance
# Models must be trained with a compact setting.

# %%
# Import ALL dependencies
import os
import geopandas as gpd
from shapely.geometry import box
import pandas as pd
import tensorflow as tf
import os
from PIL import Image
import numpy as np
import object_detection as od
import os
import tensorflow as tf
import cv2 
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from ObjectDetection import ObjectDetection

# %% [markdown]
# ## Calculate tile areas

# %%
# This is the only line you need to change to run on your own images
layer_name = "ign_belgium"

# %%
# Compile the tiles in a dataframe

layer_path = "map_layers/{}".format(layer_name)
layer_tiles_path = layer_path + "/images/tiles/"
zoom_levels = os.listdir(layer_tiles_path)
tiles = []

for zoom_level in zoom_levels:
    print("Processing zoom level {}".format(zoom_level))
    y_folders = os.listdir(layer_tiles_path + zoom_level)
    for y_folder in y_folders:
        x_files = os.listdir(layer_tiles_path + zoom_level + "/" + y_folder)
        for x_file in x_files:
            if x_file.endswith(".jpg"):
                tile_path = layer_tiles_path + zoom_level + "/" + y_folder + "/" + x_file
                tiles.append([int(zoom_level), int(y_folder), int(x_file.replace(".jpg","")), tile_path])
            
# make a dataframe
tiles = pd.DataFrame(tiles, columns=["z", "y", "x", "path"])

print("There are {} tiles in the map layer".format(len(tiles)))
# Out:
# Processing zoom level 15
# There are 21837 tiles in the map layer

# %% [markdown]
# ## Clean Tiles

# %%
# Go through each tile, if the tile is mostly white then delete it 
# (this is to remove empty tiles)
def is_valid_tile(tile_path):
    img = cv2.imread(tile_path)
    np_img = np.array(img)
    # if all the pixels are white
    if np.all(np_img == [255, 255, 255]):
        return False
    else:
        return True
    
tiles["valid"] = tiles["path"].apply(lambda x: is_valid_tile(x))

# %%
# print the number of valid tiles 
print("There are {} valid tiles in the map layer".format(len(tiles[tiles["valid"] != False])))
# delete the invalid tiles
to_delete = tiles[tiles["valid"] == False]["path"].tolist()
for tile in to_delete:
    print("Deleting {}".format(tile))
    os.remove(tile)

# %% [markdown]
# ## Export tiles to dataframe

# %%
import tile_coordinates as tc
import json

# only keep z = 15
tiles = tiles[tiles["z"] == 15]

tiles["bbox"] = tiles.apply(lambda row: tc.tile_bbox(
    row["z"], row["y"], row["x"]), axis=1)
tiles["west"] = tiles["bbox"].apply(lambda bbox: bbox.west)
tiles["east"] = tiles["bbox"].apply(lambda bbox: bbox.east)
tiles["north"] = tiles["bbox"].apply(lambda bbox: bbox.north)
tiles["south"] = tiles["bbox"].apply(lambda bbox: bbox.south)
tiles["geometry"] = tiles.apply(lambda row: box(
    row["west"], row["south"], row["east"], row["north"]), axis=1)
tile_frame_gpd = gpd.GeoDataFrame(tiles, geometry="geometry")
# drop the bbox column
tile_frame_gpd = tile_frame_gpd.drop(columns=["bbox"])
# drop geometries that are not Bounding Boxes
tile_frame_gpd = tile_frame_gpd[tile_frame_gpd["geometry"].geom_type == "Polygon"]
# exoty to escel
tile_frame_gpd.to_file(
    layer_path + "/predictions/tile_grid.shp", driver='ESRI Shapefile')

# %% [markdown]
# # Detect Images

# %%
graph_def = tf.compat.v1.GraphDef()
labels = []

# These are set to the default names from exported models, update as needed.
filename = layer_path+"\models\\azure\model.pb"
labels_filename = layer_path+"\models\\azure\labels.txt"

# Import the TF graph
with tf.io.gfile.GFile(filename, 'rb') as f:
    graph_def.ParseFromString(f.read())
    tf.import_graph_def(graph_def, name='')

# Create a list of labels.
with open(labels_filename, 'rt') as lf:
    for l in lf:
        labels.append(l.strip())
        
class TFObjectDetection(ObjectDetection):
    """Object Detection class for TensorFlow"""

    def __init__(self, graph_def, labels):
        super(TFObjectDetection, self).__init__(labels)
        self.graph = tf.compat.v1.Graph()
        with self.graph.as_default():
            input_data = tf.compat.v1.placeholder(tf.float32, [1, None, None, 3], name='Placeholder')
            tf.import_graph_def(graph_def, input_map={"Placeholder:0": input_data}, name="")

    def predict(self, preprocessed_image):
        inputs = np.array(preprocessed_image, dtype=float)[:, :, (2, 1, 0)]  # RGB -> BGR

        with tf.compat.v1.Session(graph=self.graph) as sess:
            output_tensor = sess.graph.get_tensor_by_name('model_outputs:0')
            outputs = sess.run(output_tensor, {'Placeholder:0': inputs[np.newaxis, ...]})
            return outputs[0]
        
od_model = TFObjectDetection(graph_def, labels)

# %%
import tile_coordinates as tc
import json 

# only keep z = 15
tiles = tiles[tiles["z"] == 15]
detected_eilands = gpd.GeoDataFrame(columns=["geometry", "prob", "tile"], crs="EPSG:4326", geometry="geometry")

# if the predictions folder does not exist, create it
if not os.path.exists(layer_path + "/predictions"):
    os.makedirs(layer_path + "/predictions")

for index, tile in tiles.iterrows(): 
    image = Image.open(tile["path"])
    print("Processing tile {}".format(tile["path"]), index)
    # clear the plt 
    #plt.clf()
    # add the image to the plot
    #plt.imshow(image)
    # Run the model
    predictions = od_model.predict_image(image)    
    # Calculate the bounding boox
    bbox = tc.tile_bbox(tile["z"], tile["y"], tile["x"])
    bbox.south = bbox.south
    bbox.north = bbox.north
    
    # For the popp maps 
    #bbox.south = -bbox.south
    #bbox.north = -bbox.north
        
    # tile width / bbox width
    y_resize_factor = image.width / (bbox.east - bbox.west)
    x_resize_factor = image.height / (bbox.north - bbox.south)
    # Draw bounding boxes
    for prediction in predictions:
        
        
        if prediction['probability'] > 0:
            bounding_box = prediction['boundingBox']
            left = bounding_box['left'] * image.width
            top = bounding_box['top'] * image.height
            width = bounding_box['width'] * image.width
            height = bounding_box['height'] * image.height
            bottom = top + height
            
            gpd_left = left / y_resize_factor + bbox.west
            gpd_top = bbox.north - top / x_resize_factor
            # for the popp karte:
            #gpd_top = bbox.south + top/ x_resize_factor
            gpd_width = width / y_resize_factor
            
            rect = Rectangle((left, top), width, height, linewidth=1, edgecolor='r', facecolor='none')
            gpd_polygon = box(gpd_left, gpd_top, gpd_left + gpd_width, gpd_top - (height / x_resize_factor) )
            # For popp map:
            #gpd_polygon = box(gpd_left, gpd_top, gpd_left + gpd_width, gpd_top + (height / x_resize_factor))
            detected_eilands = pd.concat([detected_eilands, gpd.GeoDataFrame({"geometry": [gpd_polygon], 
                                                                            "prob": [prediction['probability']],
                                                                            "tile": [tile["path"]],
                                                                            }, crs="EPSG:4326")])
            # add the rectangle to the plot
            

            # clear the plot 
            #plt.gca().add_patch(rect)
            #show image
            #plt.show()
            # Add label
            #plt.text(left, top, prediction['tagName'], fontsize=8, color='r', verticalalignment='bottom')
    
    # export the image            
    #plt.savefig(r"C:\Users\jaddh\code_projects\EILearn\map_layers\{}\images\predicted\{}.png".format(layer_name, str(tile["y"])+"_"+str(tile["x"])))

            
    # save the predictions json of the image 
    predictions = json.dumps(predictions)
    with open(tile["path"].replace(".jpg", ".json"), "w") as f:
        f.write(predictions)

    # every 10 tiles, save the predictions, or if it is the last tile
    if index % 20 == 0 or index == len(tiles) - 1:
        print("total number of detected eilands: {}".format(len(detected_eilands)))
        # export the geodataframe
        detected_eilands.to_file(layer_path + "/predictions/detected_eilands.shp")
# Out:
# Processing tile map_layers/ign_belgium/images/tiles/15/16615/10945.jpg 0
# total number of detected eilands: 0
# Processing tile map_layers/ign_belgium/images/tiles/15/16615/10946.jpg 1
# c:\Users\jaddh\code_projects\EILearn\venv\Lib\site-packages\geopandas\io\file.py:608: UserWarning: You are attempting to write an empty DataFrame to file. For some drivers, this operation may fail.
#   _to_file_fiona(df, filename, driver, schema, crs, mode, **kwargs)
# Processing tile map_layers/ign_belgium/images/tiles/15/16615/10947.jpg 2
# Processing tile map_layers/ign_belgium/images/tiles/15/16615/10948.jpg 3
# Processing tile map_layers/ign_belgium/images/tiles/15/16615/10949.jpg 4
# Processing tile map_layers/ign_belgium/images/tiles/15/16615/10950.jpg 5
# Processing tile map_layers/ign_belgium/images/tiles/15/16615/10951.jpg 6
# Processing tile map_layers/ign_belgium/images/tiles/15/16615/10952.jpg 7
# Processing tile map_layers/ign_belgium/images/tiles/15/16615/10953.jpg 8
# Processing tile map_layers/ign_belgium/images/tiles/15/16615/10954.jpg 9
# Processing tile map_layers/ign_belgium/images/tiles/15/16615/10955.jpg 10
# Processing tile map_layers/ign_belgium/images/tiles/15/16615/10956.jpg 11
# C:\Users\jaddh\AppData\Local\Temp\ipykernel_14684\300741896.py:55: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   detected_eilands = pd.concat([detected_eilands, gpd.GeoDataFrame({"geometry": [gpd_polygon],
# Processing tile map_layers/ign_belgium/images/tiles/15/16615/10957.jpg 12
# Processing tile map_layers/ign_belgium/images/tiles/15/16615/10958.jpg 13
# Processing tile map_layers/ign_belgium/images/tiles/15/16615/10959.jpg 14
# Processing tile map_layers/ign_belgium/images/tiles/15/16615/10960.jpg 15
# Processing tile map_layers/ign_belgium/images/tiles/15/16615/10961.jpg 16
# Processing tile map_layers/ign_belgium/images/tiles/15/16615/10962.jpg 17
# Processing tile map_layers/ign_belgium/images/tiles/15/16615/10963.jpg 18
# Processing tile map_layers/ign_belgium/images/tiles/15/16615/10964.jpg 19
# Processing tile map_layers/ign_belgium/images/tiles/15/16615/10965.jpg 20
# total number of detected eilands: 4
# Processing tile map_layers/ign_belgium/images/tiles/15/16615/10966.jpg 21
# Processing tile map_layers/ign_belgium/images/tiles/15/16615/10967.jpg 22
# Processing tile map_layers/ign_belgium/images/tiles/15/16615/10968.jpg 23
# Processing tile map_layers/ign_belgium/images/tiles/15/16615/10969.jpg 24
# Processing tile map_layers/ign_belgium/images/tiles/15/16615/10970.jpg 25
# Processing tile map_layers/ign_belgium/images/tiles/15/16615/10971.jpg 26
# Processing tile map_layers/ign_belgium/images/tiles/15/16616/10945.jpg 27
# Processing tile map_layers/ign_belgium/images/tiles/15/16616/10946.jpg 28
# Processing tile map_layers/ign_belgium/images/tiles/15/16616/10947.jpg 29
# Processing tile map_layers/ign_belgium/images/tiles/15/16616/10948.jpg 30
# Processing tile map_layers/ign_belgium/images/tiles/15/16616/10949.jpg 31
# Processing tile map_layers/ign_belgium/images/tiles/15/16616/10950.jpg 32
# Processing tile map_layers/ign_belgium/images/tiles/15/16616/10951.jpg 33
# Processing tile map_layers/ign_belgium/images/tiles/15/16616/10952.jpg 34
# Processing tile map_layers/ign_belgium/images/tiles/15/16616/10953.jpg 35
# Processing tile map_layers/ign_belgium/images/tiles/15/16616/10954.jpg 36
# Processing tile map_layers/ign_belgium/images/tiles/15/16616/10955.jpg 37
# Processing tile map_layers/ign_belgium/images/tiles/15/16616/10956.jpg 38
# Processing tile map_layers/ign_belgium/images/tiles/15/16616/10957.jpg 39
# Processing tile map_layers/ign_belgium/images/tiles/15/16616/10958.jpg 40
# total number of detected eilands: 9
# Processing tile map_layers/ign_belgium/images/tiles/15/16616/10959.jpg 41
# Processing tile map_layers/ign_belgium/images/tiles/15/16616/10960.jpg 42
# Processing tile map_layers/ign_belgium/images/tiles/15/16616/10961.jpg 43
# Processing tile map_layers/ign_belgium/images/tiles/15/16616/10962.jpg 44
# Processing tile map_layers/ign_belgium/images/tiles/15/16616/10963.jpg 45
# Processing tile map_layers/ign_belgium/images/tiles/15/16616/10964.jpg 46
# Processing tile map_layers/ign_belgium/images/tiles/15/16616/10965.jpg 47
# Processing tile map_layers/ign_belgium/images/tiles/15/16616/10966.jpg 48
# Processing tile map_layers/ign_belgium/images/tiles/15/16616/10967.jpg 49
# Processing tile map_layers/ign_belgium/images/tiles/15/16616/10968.jpg 50
# Processing tile map_layers/ign_belgium/images/tiles/15/16616/10969.jpg 51
# Processing tile map_layers/ign_belgium/images/tiles/15/16616/10970.jpg 52
# Processing tile map_layers/ign_belgium/images/tiles/15/16616/10971.jpg 53
# Processing tile map_layers/ign_belgium/images/tiles/15/16617/10945.jpg 54
# Processing tile map_layers/ign_belgium/images/tiles/15/16617/10946.jpg 55
# Processing tile map_layers/ign_belgium/images/tiles/15/16617/10947.jpg 56
# Processing tile map_layers/ign_belgium/images/tiles/15/16617/10948.jpg 57
# Processing tile map_layers/ign_belgium/images/tiles/15/16617/10949.jpg 58
# Processing tile map_layers/ign_belgium/images/tiles/15/16617/10950.jpg 59
# Processing tile map_layers/ign_belgium/images/tiles/15/16617/10951.jpg 60
# total number of detected eilands: 16
# Processing tile map_layers/ign_belgium/images/tiles/15/16617/10952.jpg 61
# Processing tile map_layers/ign_belgium/images/tiles/15/16617/10953.jpg 62
# Processing tile map_layers/ign_belgium/images/tiles/15/16617/10954.jpg 63
# Processing tile map_layers/ign_belgium/images/tiles/15/16617/10955.jpg 64
# Processing tile map_layers/ign_belgium/images/tiles/15/16617/10956.jpg 65
# Processing tile map_layers/ign_belgium/images/tiles/15/16617/10957.jpg 66
# Processing tile map_layers/ign_belgium/images/tiles/15/16617/10958.jpg 67
# Processing tile map_layers/ign_belgium/images/tiles/15/16617/10959.jpg 68
# Processing tile map_layers/ign_belgium/images/tiles/15/16617/10960.jpg 69
# Processing tile map_layers/ign_belgium/images/tiles/15/16617/10961.jpg 70
# Processing tile map_layers/ign_belgium/images/tiles/15/16617/10962.jpg 71
# Processing tile map_layers/ign_belgium/images/tiles/15/16617/10963.jpg 72
# Processing tile map_layers/ign_belgium/images/tiles/15/16617/10964.jpg 73
# Processing tile map_layers/ign_belgium/images/tiles/15/16617/10965.jpg 74
# Processing tile map_layers/ign_belgium/images/tiles/15/16617/10966.jpg 75
# Processing tile map_layers/ign_belgium/images/tiles/15/16617/10967.jpg 76
# Processing tile map_layers/ign_belgium/images/tiles/15/16617/10968.jpg 77
# Processing tile map_layers/ign_belgium/images/tiles/15/16617/10969.jpg 78
# Processing tile map_layers/ign_belgium/images/tiles/15/16617/10970.jpg 79
# Processing tile map_layers/ign_belgium/images/tiles/15/16617/10971.jpg 80
# total number of detected eilands: 52
# Processing tile map_layers/ign_belgium/images/tiles/15/16618/10945.jpg 81
# Processing tile map_layers/ign_belgium/images/tiles/15/16618/10946.jpg 82
# Processing tile map_layers/ign_belgium/images/tiles/15/16618/10947.jpg 83
# Processing tile map_layers/ign_belgium/images/tiles/15/16618/10948.jpg 84
# Processing tile map_layers/ign_belgium/images/tiles/15/16618/10949.jpg 85
# Processing tile map_layers/ign_belgium/images/tiles/15/16618/10950.jpg 86
# Processing tile map_layers/ign_belgium/images/tiles/15/16618/10951.jpg 87
# Processing tile map_layers/ign_belgium/images/tiles/15/16618/10952.jpg 88
# Processing tile map_layers/ign_belgium/images/tiles/15/16618/10953.jpg 89
# Processing tile map_layers/ign_belgium/images/tiles/15/16618/10954.jpg 90
# Processing tile map_layers/ign_belgium/images/tiles/15/16618/10955.jpg 91
# Processing tile map_layers/ign_belgium/images/tiles/15/16618/10956.jpg 92
# Processing tile map_layers/ign_belgium/images/tiles/15/16618/10957.jpg 93
# Processing tile map_layers/ign_belgium/images/tiles/15/16618/10958.jpg 94
# Processing tile map_layers/ign_belgium/images/tiles/15/16618/10959.jpg 95
# Processing tile map_layers/ign_belgium/images/tiles/15/16618/10960.jpg 96
# Processing tile map_layers/ign_belgium/images/tiles/15/16618/10961.jpg 97
# Processing tile map_layers/ign_belgium/images/tiles/15/16618/10962.jpg 98
# Processing tile map_layers/ign_belgium/images/tiles/15/16618/10963.jpg 99
# Processing tile map_layers/ign_belgium/images/tiles/15/16618/10964.jpg 100
# total number of detected eilands: 91
# Processing tile map_layers/ign_belgium/images/tiles/15/16618/10965.jpg 101
# Processing tile map_layers/ign_belgium/images/tiles/15/16618/10966.jpg 102
# Processing tile map_layers/ign_belgium/images/tiles/15/16618/10967.jpg 103
# Processing tile map_layers/ign_belgium/images/tiles/15/16618/10968.jpg 104
# Processing tile map_layers/ign_belgium/images/tiles/15/16618/10969.jpg 105
# Processing tile map_layers/ign_belgium/images/tiles/15/16618/10970.jpg 106
# Processing tile map_layers/ign_belgium/images/tiles/15/16618/10971.jpg 107
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10945.jpg 108
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10946.jpg 109
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10947.jpg 110
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10948.jpg 111
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10949.jpg 112
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10950.jpg 113
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10951.jpg 114
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10952.jpg 115
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10953.jpg 116
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10954.jpg 117
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10955.jpg 118
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10956.jpg 119
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10957.jpg 120
# total number of detected eilands: 115
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10958.jpg 121
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10959.jpg 122
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10960.jpg 123
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10961.jpg 124
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10962.jpg 125
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10963.jpg 126
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10964.jpg 127
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10965.jpg 128
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10966.jpg 129
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10967.jpg 130
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10968.jpg 131
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10969.jpg 132
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10970.jpg 133
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10971.jpg 134
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10972.jpg 135
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10973.jpg 136
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10974.jpg 137
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10975.jpg 138
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10976.jpg 139
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10977.jpg 140
# total number of detected eilands: 176
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10978.jpg 141
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10979.jpg 142
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10980.jpg 143
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10981.jpg 144
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10982.jpg 145
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10983.jpg 146
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10984.jpg 147
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10985.jpg 148
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10986.jpg 149
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10987.jpg 150
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10988.jpg 151
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10989.jpg 152
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10990.jpg 153
# Processing tile map_layers/ign_belgium/images/tiles/15/16619/10997.jpg 154
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10945.jpg 155
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10946.jpg 156
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10947.jpg 157
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10948.jpg 158
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10949.jpg 159
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10950.jpg 160
# total number of detected eilands: 176
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10951.jpg 161
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10952.jpg 162
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10953.jpg 163
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10954.jpg 164
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10955.jpg 165
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10956.jpg 166
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10957.jpg 167
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10958.jpg 168
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10959.jpg 169
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10960.jpg 170
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10961.jpg 171
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10962.jpg 172
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10963.jpg 173
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10964.jpg 174
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10965.jpg 175
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10966.jpg 176
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10967.jpg 177
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10968.jpg 178
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10969.jpg 179
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10970.jpg 180
# total number of detected eilands: 235
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10971.jpg 181
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10972.jpg 182
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10973.jpg 183
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10974.jpg 184
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10975.jpg 185
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10976.jpg 186
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10977.jpg 187
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10978.jpg 188
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10979.jpg 189
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10980.jpg 190
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10981.jpg 191
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10982.jpg 192
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10983.jpg 193
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10984.jpg 194
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10985.jpg 195
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10986.jpg 196
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10987.jpg 197
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10988.jpg 198
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10989.jpg 199
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10990.jpg 200
# total number of detected eilands: 257
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10991.jpg 201
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10992.jpg 202
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10993.jpg 203
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10994.jpg 204
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10995.jpg 205
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10996.jpg 206
# Processing tile map_layers/ign_belgium/images/tiles/15/16620/10997.jpg 207
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10945.jpg 208
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10946.jpg 209
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10947.jpg 210
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10948.jpg 211
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10949.jpg 212
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10950.jpg 213
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10951.jpg 214
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10952.jpg 215
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10953.jpg 216
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10954.jpg 217
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10955.jpg 218
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10956.jpg 219
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10957.jpg 220
# total number of detected eilands: 271
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10958.jpg 221
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10959.jpg 222
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10960.jpg 223
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10961.jpg 224
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10962.jpg 225
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10963.jpg 226
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10964.jpg 227
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10965.jpg 228
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10966.jpg 229
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10967.jpg 230
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10968.jpg 231
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10969.jpg 232
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10970.jpg 233
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10971.jpg 234
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10972.jpg 235
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10973.jpg 236
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10974.jpg 237
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10975.jpg 238
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10976.jpg 239
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10977.jpg 240
# total number of detected eilands: 325
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10978.jpg 241
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10979.jpg 242
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10980.jpg 243
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10981.jpg 244
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10982.jpg 245
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10983.jpg 246
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10984.jpg 247
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10985.jpg 248
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10986.jpg 249
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10987.jpg 250
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10988.jpg 251
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10989.jpg 252
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10990.jpg 253
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10991.jpg 254
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10992.jpg 255
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10993.jpg 256
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10994.jpg 257
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10995.jpg 258
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10996.jpg 259
# Processing tile map_layers/ign_belgium/images/tiles/15/16621/10997.jpg 260
# total number of detected eilands: 394
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10945.jpg 261
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10946.jpg 262
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10947.jpg 263
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10948.jpg 264
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10949.jpg 265
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10950.jpg 266
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10951.jpg 267
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10952.jpg 268
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10953.jpg 269
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10954.jpg 270
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10955.jpg 271
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10956.jpg 272
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10957.jpg 273
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10958.jpg 274
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10959.jpg 275
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10960.jpg 276
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10961.jpg 277
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10962.jpg 278
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10963.jpg 279
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10964.jpg 280
# total number of detected eilands: 435
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10965.jpg 281
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10966.jpg 282
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10967.jpg 283
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10968.jpg 284
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10969.jpg 285
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10970.jpg 286
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10971.jpg 287
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10972.jpg 288
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10973.jpg 289
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10974.jpg 290
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10975.jpg 291
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10976.jpg 292
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10977.jpg 293
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10978.jpg 294
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10979.jpg 295
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10980.jpg 296
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10981.jpg 297
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10982.jpg 298
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10983.jpg 299
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10984.jpg 300
# total number of detected eilands: 555
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10985.jpg 301
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10986.jpg 302
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10987.jpg 303
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10988.jpg 304
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10989.jpg 305
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10990.jpg 306
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10991.jpg 307
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10992.jpg 308
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10993.jpg 309
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10994.jpg 310
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10995.jpg 311
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10996.jpg 312
# Processing tile map_layers/ign_belgium/images/tiles/15/16622/10997.jpg 313
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10945.jpg 314
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10946.jpg 315
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10947.jpg 316
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10948.jpg 317
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10949.jpg 318
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10950.jpg 319
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10951.jpg 320
# total number of detected eilands: 621
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10952.jpg 321
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10953.jpg 322
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10954.jpg 323
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10955.jpg 324
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10956.jpg 325
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10957.jpg 326
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10958.jpg 327
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10959.jpg 328
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10960.jpg 329
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10961.jpg 330
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10962.jpg 331
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10963.jpg 332
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10964.jpg 333
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10965.jpg 334
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10966.jpg 335
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10967.jpg 336
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10968.jpg 337
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10969.jpg 338
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10970.jpg 339
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10971.jpg 340
# total number of detected eilands: 714
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10972.jpg 341
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10973.jpg 342
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10974.jpg 343
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10975.jpg 344
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10976.jpg 345
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10977.jpg 346
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10978.jpg 347
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10979.jpg 348
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10980.jpg 349
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10981.jpg 350
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10982.jpg 351
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10983.jpg 352
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10984.jpg 353
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10985.jpg 354
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10986.jpg 355
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10987.jpg 356
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10988.jpg 357
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10989.jpg 358
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10990.jpg 359
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10991.jpg 360
# total number of detected eilands: 828
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10992.jpg 361
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10993.jpg 362
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10994.jpg 363
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10995.jpg 364
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10996.jpg 365
# Processing tile map_layers/ign_belgium/images/tiles/15/16623/10997.jpg 366
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10945.jpg 367
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10946.jpg 368
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10947.jpg 369
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10948.jpg 370
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10949.jpg 371
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10950.jpg 372
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10951.jpg 373
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10952.jpg 374
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10953.jpg 375
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10954.jpg 376
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10955.jpg 377
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10956.jpg 378
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10957.jpg 379
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10958.jpg 380
# total number of detected eilands: 870
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10959.jpg 381
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10960.jpg 382
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10961.jpg 383
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10962.jpg 384
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10963.jpg 385
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10964.jpg 386
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10965.jpg 387
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10966.jpg 388
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10967.jpg 389
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10968.jpg 390
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10969.jpg 391
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10970.jpg 392
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10971.jpg 393
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10972.jpg 394
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10973.jpg 395
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10974.jpg 396
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10975.jpg 397
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10976.jpg 398
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10977.jpg 399
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10978.jpg 400
# total number of detected eilands: 1016
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10979.jpg 401
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10980.jpg 402
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10981.jpg 403
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10982.jpg 404
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10983.jpg 405
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10984.jpg 406
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10985.jpg 407
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10986.jpg 408
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10987.jpg 409
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10988.jpg 410
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10989.jpg 411
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10990.jpg 412
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10991.jpg 413
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10992.jpg 414
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10993.jpg 415
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10994.jpg 416
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10995.jpg 417
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10996.jpg 418
# Processing tile map_layers/ign_belgium/images/tiles/15/16624/10997.jpg 419
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10945.jpg 420
# total number of detected eilands: 1104
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10946.jpg 421
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10947.jpg 422
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10948.jpg 423
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10949.jpg 424
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10950.jpg 425
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10951.jpg 426
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10952.jpg 427
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10953.jpg 428
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10954.jpg 429
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10955.jpg 430
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10956.jpg 431
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10957.jpg 432
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10958.jpg 433
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10959.jpg 434
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10960.jpg 435
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10961.jpg 436
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10962.jpg 437
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10963.jpg 438
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10964.jpg 439
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10965.jpg 440
# total number of detected eilands: 1153
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10966.jpg 441
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10967.jpg 442
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10968.jpg 443
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10969.jpg 444
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10970.jpg 445
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10971.jpg 446
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10972.jpg 447
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10973.jpg 448
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10974.jpg 449
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10975.jpg 450
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10976.jpg 451
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10977.jpg 452
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10978.jpg 453
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10979.jpg 454
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10980.jpg 455
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10981.jpg 456
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10982.jpg 457
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10983.jpg 458
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10984.jpg 459
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10985.jpg 460
# total number of detected eilands: 1317
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10986.jpg 461
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10987.jpg 462
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10988.jpg 463
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10989.jpg 464
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10990.jpg 465
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10991.jpg 466
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10992.jpg 467
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10993.jpg 468
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10994.jpg 469
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10995.jpg 470
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10996.jpg 471
# Processing tile map_layers/ign_belgium/images/tiles/15/16625/10997.jpg 472
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10945.jpg 473
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10946.jpg 474
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10947.jpg 475
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10948.jpg 476
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10949.jpg 477
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10950.jpg 478
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10951.jpg 479
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10952.jpg 480
# total number of detected eilands: 1363
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10953.jpg 481
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10954.jpg 482
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10955.jpg 483
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10956.jpg 484
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10957.jpg 485
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10958.jpg 486
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10959.jpg 487
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10960.jpg 488
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10961.jpg 489
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10962.jpg 490
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10963.jpg 491
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10964.jpg 492
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10965.jpg 493
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10966.jpg 494
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10967.jpg 495
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10968.jpg 496
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10969.jpg 497
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10970.jpg 498
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10971.jpg 499
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10972.jpg 500
# total number of detected eilands: 1505
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10973.jpg 501
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10974.jpg 502
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10975.jpg 503
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10976.jpg 504
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10977.jpg 505
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10978.jpg 506
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10979.jpg 507
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10980.jpg 508
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10981.jpg 509
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10982.jpg 510
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10983.jpg 511
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10984.jpg 512
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10985.jpg 513
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10986.jpg 514
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10987.jpg 515
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10988.jpg 516
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10989.jpg 517
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10990.jpg 518
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10991.jpg 519
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10992.jpg 520
# total number of detected eilands: 1606
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10993.jpg 521
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10994.jpg 522
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10995.jpg 523
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10996.jpg 524
# Processing tile map_layers/ign_belgium/images/tiles/15/16626/10997.jpg 525
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10945.jpg 526
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10946.jpg 527
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10947.jpg 528
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10948.jpg 529
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10949.jpg 530
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10950.jpg 531
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10951.jpg 532
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10952.jpg 533
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10953.jpg 534
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10954.jpg 535
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10955.jpg 536
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10956.jpg 537
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10957.jpg 538
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10958.jpg 539
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10959.jpg 540
# total number of detected eilands: 1648
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10960.jpg 541
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10961.jpg 542
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10962.jpg 543
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10963.jpg 544
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10964.jpg 545
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10965.jpg 546
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10966.jpg 547
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10967.jpg 548
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10968.jpg 549
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10969.jpg 550
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10970.jpg 551
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10971.jpg 552
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10972.jpg 553
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10973.jpg 554
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10974.jpg 555
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10975.jpg 556
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10976.jpg 557
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10977.jpg 558
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10978.jpg 559
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10979.jpg 560
# total number of detected eilands: 1802
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10980.jpg 561
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10981.jpg 562
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10982.jpg 563
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10983.jpg 564
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10984.jpg 565
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10985.jpg 566
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10986.jpg 567
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10987.jpg 568
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10988.jpg 569
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10989.jpg 570
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10990.jpg 571
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10991.jpg 572
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10992.jpg 573
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10993.jpg 574
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10994.jpg 575
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10995.jpg 576
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10996.jpg 577
# Processing tile map_layers/ign_belgium/images/tiles/15/16627/10997.jpg 578
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10945.jpg 579
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10946.jpg 580
# total number of detected eilands: 1866
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10947.jpg 581
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10948.jpg 582
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10949.jpg 583
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10950.jpg 584
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10951.jpg 585
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10952.jpg 586
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10953.jpg 587
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10954.jpg 588
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10955.jpg 589
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10956.jpg 590
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10957.jpg 591
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10958.jpg 592
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10959.jpg 593
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10960.jpg 594
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10961.jpg 595
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10962.jpg 596
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10963.jpg 597
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10964.jpg 598
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10965.jpg 599
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10966.jpg 600
# total number of detected eilands: 1919
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10967.jpg 601
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10968.jpg 602
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10969.jpg 603
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10970.jpg 604
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10971.jpg 605
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10972.jpg 606
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10973.jpg 607
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10974.jpg 608
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10975.jpg 609
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10976.jpg 610
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10977.jpg 611
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10978.jpg 612
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10979.jpg 613
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10980.jpg 614
# Processing tile map_layers/ign_belgium/images/tiles/15/16628/10981.jpg 615
# ...
# Processing tile map_layers/ign_belgium/images/tiles/15/16852/11010.jpg 21635
# Processing tile map_layers/ign_belgium/images/tiles/15/16852/11011.jpg 21636
# Processing tile map_layers/ign_belgium/images/tiles/15/16852/11012.jpg 21637
# Processing tile map_layers/ign_belgium/images/tiles/15/16852/11013.jpg 21638
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10915.jpg 21639
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10916.jpg 21640
# total number of detected eilands: 68190
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10917.jpg 21641
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10918.jpg 21642
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10919.jpg 21643
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10920.jpg 21644
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10921.jpg 21645
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10922.jpg 21646
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10923.jpg 21647
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10924.jpg 21648
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10925.jpg 21649
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10926.jpg 21650
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10927.jpg 21651
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10928.jpg 21652
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10929.jpg 21653
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10930.jpg 21654
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10931.jpg 21655
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10932.jpg 21656
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10933.jpg 21657
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10934.jpg 21658
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10935.jpg 21659
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10936.jpg 21660
# total number of detected eilands: 68234
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10937.jpg 21661
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10938.jpg 21662
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10939.jpg 21663
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10940.jpg 21664
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10941.jpg 21665
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10942.jpg 21666
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10943.jpg 21667
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10944.jpg 21668
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10945.jpg 21669
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10946.jpg 21670
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10947.jpg 21671
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10948.jpg 21672
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10949.jpg 21673
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10950.jpg 21674
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10951.jpg 21675
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10952.jpg 21676
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10953.jpg 21677
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10954.jpg 21678
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10955.jpg 21679
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10956.jpg 21680
# total number of detected eilands: 68355
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10957.jpg 21681
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10958.jpg 21682
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10959.jpg 21683
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10960.jpg 21684
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10961.jpg 21685
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10962.jpg 21686
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10963.jpg 21687
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10964.jpg 21688
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10965.jpg 21689
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10966.jpg 21690
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10967.jpg 21691
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10968.jpg 21692
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10969.jpg 21693
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10970.jpg 21694
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10971.jpg 21695
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10972.jpg 21696
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10973.jpg 21697
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10974.jpg 21698
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10975.jpg 21699
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10976.jpg 21700
# total number of detected eilands: 68419
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10977.jpg 21701
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10978.jpg 21702
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10979.jpg 21703
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10980.jpg 21704
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10981.jpg 21705
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10982.jpg 21706
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10983.jpg 21707
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10984.jpg 21708
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10985.jpg 21709
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10986.jpg 21710
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10987.jpg 21711
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10988.jpg 21712
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10989.jpg 21713
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10990.jpg 21714
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10991.jpg 21715
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10992.jpg 21716
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10993.jpg 21717
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10994.jpg 21718
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10995.jpg 21719
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10996.jpg 21720
# total number of detected eilands: 68484
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10997.jpg 21721
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10998.jpg 21722
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/10999.jpg 21723
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/11000.jpg 21724
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/11001.jpg 21725
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/11002.jpg 21726
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/11003.jpg 21727
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/11004.jpg 21728
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/11005.jpg 21729
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/11006.jpg 21730
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/11007.jpg 21731
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/11008.jpg 21732
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/11009.jpg 21733
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/11010.jpg 21734
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/11011.jpg 21735
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/11012.jpg 21736
# Processing tile map_layers/ign_belgium/images/tiles/15/16853/11013.jpg 21737
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10915.jpg 21738
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10916.jpg 21739
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10917.jpg 21740
# total number of detected eilands: 68495
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10918.jpg 21741
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10919.jpg 21742
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10920.jpg 21743
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10921.jpg 21744
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10922.jpg 21745
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10923.jpg 21746
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10924.jpg 21747
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10925.jpg 21748
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10926.jpg 21749
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10927.jpg 21750
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10928.jpg 21751
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10929.jpg 21752
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10930.jpg 21753
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10931.jpg 21754
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10932.jpg 21755
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10933.jpg 21756
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10934.jpg 21757
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10935.jpg 21758
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10936.jpg 21759
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10937.jpg 21760
# total number of detected eilands: 68544
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10938.jpg 21761
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10939.jpg 21762
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10940.jpg 21763
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10941.jpg 21764
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10942.jpg 21765
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10943.jpg 21766
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10944.jpg 21767
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10945.jpg 21768
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10946.jpg 21769
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10947.jpg 21770
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10948.jpg 21771
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10949.jpg 21772
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10950.jpg 21773
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10951.jpg 21774
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10952.jpg 21775
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10953.jpg 21776
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10954.jpg 21777
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10955.jpg 21778
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10956.jpg 21779
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10957.jpg 21780
# total number of detected eilands: 68643
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10958.jpg 21781
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10959.jpg 21782
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10960.jpg 21783
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10961.jpg 21784
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10962.jpg 21785
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10963.jpg 21786
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10964.jpg 21787
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10965.jpg 21788
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10966.jpg 21789
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10967.jpg 21790
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10968.jpg 21791
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10969.jpg 21792
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10970.jpg 21793
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10971.jpg 21794
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10972.jpg 21795
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10973.jpg 21796
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10974.jpg 21797
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10975.jpg 21798
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10976.jpg 21799
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10977.jpg 21800
# total number of detected eilands: 68726
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10978.jpg 21801
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10979.jpg 21802
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10980.jpg 21803
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10981.jpg 21804
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10982.jpg 21805
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10983.jpg 21806
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10984.jpg 21807
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10985.jpg 21808
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10986.jpg 21809
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10987.jpg 21810
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10988.jpg 21811
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10989.jpg 21812
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10990.jpg 21813
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10991.jpg 21814
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10992.jpg 21815
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10993.jpg 21816
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10994.jpg 21817
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10995.jpg 21818
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10996.jpg 21819
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10997.jpg 21820
# total number of detected eilands: 68811
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10998.jpg 21821
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/10999.jpg 21822
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/11000.jpg 21823
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/11001.jpg 21824
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/11002.jpg 21825
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/11003.jpg 21826
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/11004.jpg 21827
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/11005.jpg 21828
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/11006.jpg 21829
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/11007.jpg 21830
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/11008.jpg 21831
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/11009.jpg 21832
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/11010.jpg 21833
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/11011.jpg 21834
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/11012.jpg 21835
# Processing tile map_layers/ign_belgium/images/tiles/15/16854/11013.jpg 21836
# total number of detected eilands: 68815
